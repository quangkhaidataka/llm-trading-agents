# %% [markdown]
# # Results
#
# Equity curve, metrics table (Sharpe, Sortino, MaxDD, turnover, avg holding period)
# vs buy & hold, ablation comparison, and the conviction reliability diagram.
# Populated at milestones M4-M5.

# %%
from config import config
from src.backtest.run_backtest import run_backtest

# metrics = run_backtest(config)  # M4
